# %% [markdown]
# # Мультимодальный RAG-пайплайн: Результаты анализа
#
# **Система:** Мультимодальная RAG для русско-казахских технических документов
# **Типы блоков:** header, text, list, table, no_text → chart, image
# **ИИ-модели:** CLIP, BLIP, SBERT, GPT API

# %% [markdown]
# ---
# ## 1. Настройка среды

# %%
import sys, os, logging
import warnings
warnings.filterwarnings('ignore')

# Корень проекта
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
os.chdir(PROJECT_ROOT)

# Логирование
logging.basicConfig(level=logging.INFO, format='%(name)s - %(message)s')
logger = logging.getLogger('notebook')

# Путь к PDF
PDF_PATH = 'data/input_pdfs/diploma_example.pdf'
print(f'PDF: {PDF_PATH}')
print(f'Exists: {os.path.exists(PDF_PATH)}')
# Out:
# PDF: data/input_pdfs/diploma_example.pdf
# Exists: True

# %%
# Проверка зависимостей
print('=== Проверка зависимостей ===')

# Tesseract OCR
try:
    import pytesseract
    version = pytesseract.get_tesseract_version()
    print(f'Tesseract OCR: v{version}')
except Exception as e:
    print(f'Tesseract OCR: НЕ УСТАНОВЛЕН!')
    print(f'  Скачайте: https://github.com/UB-Mannheim/tesseract/wiki')
    print(f'  При установке выберите языки: Russian, Kazakh, English')
    print(f'  Добавьте в PATH: C:\\Program Files\\Tesseract-OCR')

# PyMuPDF
import fitz
print(f'PyMuPDF: v{fitz.version[0]}')

# transformers (CLIP, BLIP)
try:
    import transformers
    print(f'Transformers: v{transformers.__version__}')
except ImportError:
    print('Transformers: НЕ УСТАНОВЛЕН (pip install transformers)')

# sentence-transformers (SBERT)
try:
    import sentence_transformers
    print(f'Sentence-Transformers: v{sentence_transformers.__version__}')
except ImportError:
    print('Sentence-Transformers: НЕ УСТАНОВЛЕН')

# FAISS
try:
    import faiss
    print(f'FAISS: OK')
except ImportError:
    print('FAISS: НЕ УСТАНОВЛЕН (pip install faiss-cpu)')

print()
print(f'Документ: {os.path.basename(PDF_PATH)}')
print(f'Страниц: {len(fitz.open(PDF_PATH))}')
# Out:
# === Проверка зависимостей ===
# Tesseract OCR: v5.5.0
# PyMuPDF: v1.27.2
# Transformers: v5.3.0
# faiss.loader - Loading faiss with AVX2 support.
# faiss.loader - Successfully loaded faiss with AVX2 support.
# Sentence-Transformers: v5.3.0
# FAISS: OK
#
# Документ: diploma_example.pdf
# Страниц: 41

# %% [markdown]
# ---
# ## 2. Этап 1 — Извлечение блоков из PDF
#
# PyMuPDF извлекает текстовые блоки и изображения.
# `BlockClassifier` (правила, без ИИ) определяет тип: **header**, **text**, **list**, **table**, **no_text**.

# %%
import fitz
from src.pipeline.page_analyzer import PageAnalyzer

doc = fitz.open(PDF_PATH)
analyzer = PageAnalyzer()

all_blocks = []
for page_num in range(len(doc)):
    page = doc[page_num]
    blocks = analyzer.analyze_page(page, page_num + 1)
    all_blocks.extend(blocks)
doc.close()

print(f'Всего страниц: {len(fitz.open(PDF_PATH))}')
print(f'Всего блоков: {len(all_blocks)}')
print()

# Подсчёт типов
from collections import Counter
type_counts = Counter(b.block_type for b in all_blocks)
for t, c in sorted(type_counts.items(), key=lambda x: -x[1]):
    print(f'  {t:10s}: {c}')
# Out:
# Всего страниц: 41
# Всего блоков: 214
#
#   text      : 77
#   table     : 77
#   no_text   : 38
#   header    : 12
#   list      : 10

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'DejaVu Sans'

fig, ax = plt.subplots(figsize=(8, 4))
types = list(type_counts.keys())
counts = list(type_counts.values())
colors_map = {
    'header': '#4ECDC4', 'text': '#45B7D1', 'list': '#96CEB4',
    'table': '#FFEAA7', 'no_text': '#DFE6E9', 'chart': '#FF6B6B',
    'image': '#A29BFE'
}
bar_colors = [colors_map.get(t, '#95A5A6') for t in types]

bars = ax.barh(types, counts, color=bar_colors, edgecolor='white', linewidth=1.5)
for bar, count in zip(bars, counts):
    ax.text(bar.get_width() + 0.5, bar.get_y() + bar.get_height()/2,
            str(count), va='center', fontsize=11, fontweight='bold')

ax.set_xlabel('Количество блоков')
ax.set_title('Распределение типов блоков (Этап 1)')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
os.makedirs('report/img', exist_ok=True)
plt.savefig('report/img/block_types.png', dpi=150, bbox_inches='tight')
plt.show()
print('Сохранено: report/img/block_types.png')
# Out:
# Сохранено: report/img/block_types.png

# %%
# Примеры каждого типа блока
print('=' * 60)
print('ПРИМЕРЫ БЛОКОВ ПО ТИПАМ')
print('=' * 60)

shown_types = set()
for block in all_blocks:
    if block.block_type not in shown_types and block.text:
        shown_types.add(block.block_type)
        text_preview = block.text[:120].replace('\n', ' ')
        if len(block.text) > 120:
            text_preview += '...'
        print(f'\n[{block.block_type:10s}] Стр. {block.page_num}:')
        print(f'  {text_preview}')
# Out:
# ============================================================
# ПРИМЕРЫ БЛОКОВ ПО ТИПАМ
# ============================================================
#
# [header    ] Стр. 1:
#   МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИК КАЗАХСТАН
#
# [text      ] Стр. 1:
#   Казахский национальный исследовательский технический университет
#
# [table     ] Стр. 4:
#   1 M. C. RAO. Pulsed laser deposition -ablation mechanism andapplications  // Modern Physics. – 2013. – Vol. 22. – Р. 355...
#
# [no_text   ] Стр. 11:
#   12
#
# [list      ] Стр. 11:
#   1.1  Метод импульсного лазерного осаждения (PLD)  12    1.2  Рост пленки на поверхности подложки  15    1.3  Оксидные ма...

# %% [markdown]
# ---
# ## 3. Этап 2 — Классификация изображений (CLIP)
#
# Все блоки `no_text` — это изображения. CLIP (ИИ) смотрит на каждое и определяет:
# - **chart** — графики, диаграммы, гистограммы (нужна транскрипция)
# - **image** — фотографии, логотипы, схемы (краткое описание)

# %%
from src.preprocessing.image_extractor import ImageExtractor
from src.preprocessing.image_captioner import ImageClassifier

# Извлечение изображений
extractor = ImageExtractor(min_width=50, min_height=50)
doc_name = os.path.splitext(os.path.basename(PDF_PATH))[0]
images_dir = os.path.join('data/images', doc_name)
extracted_images = extractor.extract_from_pdf(PDF_PATH, output_dir=images_dir)
print(f'Извлечено изображений: {len(extracted_images)}')

# CLIP классификация
classifier = ImageClassifier(use_clip=True)

if extracted_images:
    classifications = classifier.classify_batch(extracted_images)

    # Разделение
    chart_images = [
        (img, cls) for img, cls in zip(extracted_images, classifications)
        if cls['block_type'] == 'chart'
    ]
    photo_images = [
        (img, cls) for img, cls in zip(extracted_images, classifications)
        if cls['block_type'] == 'image'
    ]

    print(f'\nРезультаты CLIP:')
    print(f'  Charts (графики): {len(chart_images)}')
    print(f'  Images (фото):    {len(photo_images)}')
    print()
    for i, (img, cls) in enumerate(zip(extracted_images, classifications)):
        bt = cls['block_type']
        cs = cls['chart_score']
        ims = cls['image_score']
        conf = cls['confidence']
        print(f'  [{i+1}] Стр. {img.page_num+1}: {bt:5s}  '
              f'(chart={cs:.3f}, image={ims:.3f}, conf={conf:.3f})')
else:
    chart_images = []
    photo_images = []
    print('Изображения не найдены.')
# Out:
# src.preprocessing.image_extractor - Извлечение изображений из: data/input_pdfs/diploma_example.pdf (41 страниц)
# src.preprocessing.image_extractor - Извлечено 35 уникальных изображений (отфильтровано: 0 дубликатов)
# src.preprocessing.image_captioner -   Классификация [1/35]: стр. 2, 1087x1536px
# src.preprocessing.image_captioner - Загрузка CLIP модели (openai/clip-vit-base-patch32)...
# Извлечено изображений: 35
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/openai/clip-vit-base-patch32/3d74acf9a28c67741b2f4f2ea7635f0aaf6f0268/config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# huggingface_hub.utils._http - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/pytorch_model.bin "HTTP/1.1 302 Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: GET https://huggingface.co/api/models/openai/clip-vit-base-patch32 "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/models/openai/clip-vit-base-patch32/commits/main "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/models/openai/clip-vit-base-patch32/discussions?p=0 "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/models/openai/clip-vit-base-patch32/commits/refs%2Fpr%2F66 "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/refs%2Fpr%2F66/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/refs%2Fpr%2F66/model.safetensors "HTTP/1.1 302 Found"
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# CLIPModel LOAD REPORT from: openai/clip-vit-base-patch32
# Key                                  | Status     |  |
# -------------------------------------+------------+--+-
# vision_model.embeddings.position_ids | UNEXPECTED |  |
# text_model.embeddings.position_ids   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# httpx - HTTP Request: GET https://huggingface.co/api/models/openai/clip-vit-base-patch32/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/chat_template.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/audio_tokenizer_config.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/openai/clip-vit-base-patch32/3d74acf9a28c67741b2f4f2ea7635f0aaf6f0268/preprocessor_config.json "HTTP/1.1 200 OK"
# The image processor of type `CLIPImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/openai/clip-vit-base-patch32/3d74acf9a28c67741b2f4f2ea7635f0aaf6f0268/preprocessor_config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/openai/clip-vit-base-patch32/3d74acf9a28c67741b2f4f2ea7635f0aaf6f0268/config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/openai/clip-vit-base-patch32/3d74acf9a28c67741b2f4f2ea7635f0aaf6f0268/tokenizer_config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/models/openai/clip-vit-base-patch32/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: GET https://huggingface.co/api/models/openai/clip-vit-base-patch32/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# src.preprocessing.image_captioner - CLIP модель загружена.
# src.preprocessing.image_captioner -   Стр. 2: image (chart=0.042, image=0.291, confidence=0.873)
# src.preprocessing.image_captioner -   Классификация [2/35]: стр. 3, 1087x1536px
# src.preprocessing.image_captioner -   Стр. 3: image (chart=0.043, image=0.290, confidence=0.871)
# src.preprocessing.image_captioner -   Классификация [3/35]: стр. 5, 1087x1536px
# src.preprocessing.image_captioner -   Стр. 5: chart (chart=0.218, image=0.115, confidence=0.654)
# src.preprocessing.image_captioner -   Классификация [4/35]: стр. 7, 1087x1536px
# src.preprocessing.image_captioner -   Стр. 7: image (chart=0.023, image=0.310, confidence=0.931)
# src.preprocessing.image_captioner -   Классификация [5/35]: стр. 8, 1087x1536px
# src.preprocessing.image_captioner -   Стр. 8: image (chart=0.004, image=0.329, confidence=0.987)
# src.preprocessing.image_captioner -   Классификация [6/35]: стр. 14, 792x593px
# src.preprocessing.image_captioner -   Стр. 14: chart (chart=0.205, image=0.129, confidence=0.614)
# src.preprocessing.image_captioner -   Классификация [7/35]: стр. 15, 857x643px
# src.preprocessing.image_captioner -   Стр. 15: image (chart=0.018, image=0.315, confidence=0.946)
# src.preprocessing.image_captioner -   Классификация [8/35]: стр. 16, 463x260px
# src.preprocessing.image_captioner -   Стр. 16: image (chart=0.012, image=0.322, confidence=0.965)
# src.preprocessing.image_captioner -   Классификация [9/35]: стр. 23, 266x190px
# src.preprocessing.image_captioner -   Стр. 23: chart (chart=0.264, image=0.070, confidence=0.791)
# src.preprocessing.image_captioner -   Классификация [10/35]: стр. 23, 347x345px
# src.preprocessing.image_captioner -   Стр. 23: chart (chart=0.182, image=0.151, confidence=0.546)
# src.preprocessing.image_captioner -   Классификация [11/35]: стр. 26, 199x199px
# src.preprocessing.image_captioner -   Стр. 26: image (chart=0.032, image=0.302, confidence=0.905)
# src.preprocessing.image_captioner -   Классификация [12/35]: стр. 26, 238x221px
# src.preprocessing.image_captioner -   Стр. 26: image (chart=0.002, image=0.331, confidence=0.994)
# src.preprocessing.image_captioner -   Классификация [13/35]: стр. 26, 205x221px
# src.preprocessing.image_captioner -   Стр. 26: image (chart=0.067, image=0.266, confidence=0.799)
# src.preprocessing.image_captioner -   Классификация [14/35]: стр. 27, 254x259px
# src.preprocessing.image_captioner -   Стр. 27: image (chart=0.001, image=0.332, confidence=0.996)
# src.preprocessing.image_captioner -   Классификация [15/35]: стр. 28, 272x278px
# src.preprocessing.image_captioner -   Стр. 28: chart (chart=0.203, image=0.130, confidence=0.609)
# src.preprocessing.image_captioner -   Классификация [16/35]: стр. 28, 356x262px
# src.preprocessing.image_captioner -   Стр. 28: chart (chart=0.331, image=0.002, confidence=0.994)
# src.preprocessing.image_captioner -   Классификация [17/35]: стр. 29, 536x468px
# src.preprocessing.image_captioner -   Стр. 29: image (chart=0.019, image=0.314, confidence=0.943)
# src.preprocessing.image_captioner -   Классификация [18/35]: стр. 29, 519x472px
# src.preprocessing.image_captioner -   Стр. 29: image (chart=0.008, image=0.325, confidence=0.976)
# src.preprocessing.image_captioner -   Классификация [19/35]: стр. 29, 428x456px
# src.preprocessing.image_captioner -   Стр. 29: image (chart=0.025, image=0.309, confidence=0.926)
# src.preprocessing.image_captioner -   Классификация [20/35]: стр. 30, 631x441px
# src.preprocessing.image_captioner -   Стр. 30: image (chart=0.113, image=0.220, confidence=0.660)
# src.preprocessing.image_captioner -   Классификация [21/35]: стр. 31, 513x325px
# src.preprocessing.image_captioner -   Стр. 31: chart (chart=0.323, image=0.011, confidence=0.968)
# src.preprocessing.image_captioner -   Классификация [22/35]: стр. 33, 313x189px
# src.preprocessing.image_captioner -   Стр. 33: image (chart=0.165, image=0.169, confidence=0.506)
# src.preprocessing.image_captioner -   Классификация [23/35]: стр. 33, 349x194px
# src.preprocessing.image_captioner -   Стр. 33: chart (chart=0.271, image=0.062, confidence=0.813)
# src.preprocessing.image_captioner -   Классификация [24/35]: стр. 33, 350x190px
# src.preprocessing.image_captioner -   Стр. 33: chart (chart=0.235, image=0.098, confidence=0.706)
# src.preprocessing.image_captioner -   Классификация [25/35]: стр. 34, 336x194px
# src.preprocessing.image_captioner -   Стр. 34: chart (chart=0.258, image=0.075, confidence=0.774)
# src.preprocessing.image_captioner -   Классификация [26/35]: стр. 34, 348x216px
# src.preprocessing.image_captioner -   Стр. 34: image (chart=0.114, image=0.220, confidence=0.659)
# src.preprocessing.image_captioner -   Классификация [27/35]: стр. 35, 357x268px
# src.preprocessing.image_captioner -   Стр. 35: image (chart=0.032, image=0.301, confidence=0.903)
# src.preprocessing.image_captioner -   Классификация [28/35]: стр. 35, 293x219px
# src.preprocessing.image_captioner -   Стр. 35: image (chart=0.051, image=0.282, confidence=0.846)
# src.preprocessing.image_captioner -   Классификация [29/35]: стр. 35, 451x338px
# src.preprocessing.image_captioner -   Стр. 35: image (chart=0.041, image=0.292, confidence=0.877)
# src.preprocessing.image_captioner -   Классификация [30/35]: стр. 35, 424x318px
# src.preprocessing.image_captioner -   Стр. 35: image (chart=0.030, image=0.304, confidence=0.911)
# src.preprocessing.image_captioner -   Классификация [31/35]: стр. 36, 567x425px
# src.preprocessing.image_captioner -   Стр. 36: image (chart=0.017, image=0.316, confidence=0.949)
# src.preprocessing.image_captioner -   Классификация [32/35]: стр. 36, 547x425px
# src.preprocessing.image_captioner -   Стр. 36: image (chart=0.045, image=0.288, confidence=0.864)
# src.preprocessing.image_captioner -   Классификация [33/35]: стр. 36, 489x366px
# src.preprocessing.image_captioner -   Стр. 36: image (chart=0.042, image=0.291, confidence=0.874)
# src.preprocessing.image_captioner -   Классификация [34/35]: стр. 37, 422x316px
# src.preprocessing.image_captioner -   Стр. 37: image (chart=0.031, image=0.302, confidence=0.906)
# src.preprocessing.image_captioner -   Классификация [35/35]: стр. 37, 398x272px
# src.preprocessing.image_captioner -   Стр. 37: chart (chart=0.264, image=0.069, confidence=0.793)
# src.preprocessing.image_captioner -   Итого: 11 chart, 24 image
# Результаты CLIP:
#   Charts (графики): 11
#   Images (фото):    24
#
#   [1] Стр. 2: image  (chart=0.042, image=0.291, conf=0.873)
#   [2] Стр. 3: image  (chart=0.043, image=0.290, conf=0.871)
#   [3] Стр. 5: chart  (chart=0.218, image=0.115, conf=0.654)
#   [4] Стр. 7: image  (chart=0.023, image=0.310, conf=0.931)
#   [5] Стр. 8: image  (chart=0.004, image=0.329, conf=0.987)
#   [6] Стр. 14: chart  (chart=0.205, image=0.129, conf=0.614)
#   [7] Стр. 15: image  (chart=0.018, image=0.315, conf=0.946)
#   [8] Стр. 16: image  (chart=0.012, image=0.322, conf=0.965)
#   [9] Стр. 23: chart  (chart=0.264, image=0.070, conf=0.791)
#   [10] Стр. 23: chart  (chart=0.182, image=0.151, conf=0.546)
#   [11] Стр. 26: image  (chart=0.032, image=0.302, conf=0.905)
#   [12] Стр. 26: image  (chart=0.002, image=0.331, conf=0.994)
#   [13] Стр. 26: image  (chart=0.067, image=0.266, conf=0.799)
#   [14] Стр. 27: image  (chart=0.001, image=0.332, conf=0.996)
#   [15] Стр. 28: chart  (chart=0.203, image=0.130, conf=0.609)
#   [16] Стр. 28: chart  (chart=0.331, image=0.002, conf=0.994)
#   [17] Стр. 29: image  (chart=0.019, image=0.314, conf=0.943)
#   [18] Стр. 29: image  (chart=0.008, image=0.325, conf=0.976)
#   [19] Стр. 29: image  (chart=0.025, image=0.309, conf=0.926)
#   [20] Стр. 30: image  (chart=0.113, image=0.220, conf=0.660)
#   [21] Стр. 31: chart  (chart=0.323, image=0.011, conf=0.968)
#   [22] Стр. 33: image  (chart=0.165, image=0.169, conf=0.506)
#   [23] Стр. 33: chart  (chart=0.271, image=0.062, conf=0.813)
#   [24] Стр. 33: chart  (chart=0.235, image=0.098, conf=0.706)
#   [25] Стр. 34: chart  (chart=0.258, image=0.075, conf=0.774)
#   [26] Стр. 34: image  (chart=0.114, image=0.220, conf=0.659)
#   [27] Стр. 35: image  (chart=0.032, image=0.301, conf=0.903)
#   [28] Стр. 35: image  (chart=0.051, image=0.282, conf=0.846)
#   [29] Стр. 35: image  (chart=0.041, image=0.292, conf=0.877)
#   [30] Стр. 35: image  (chart=0.030, image=0.303, conf=0.911)
#   [31] Стр. 36: image  (chart=0.017, image=0.316, conf=0.949)
#   [32] Стр. 36: image  (chart=0.045, image=0.288, conf=0.864)
#   [33] Стр. 36: image  (chart=0.042, image=0.291, conf=0.874)
#   [34] Стр. 37: image  (chart=0.032, image=0.302, conf=0.906)
#   [35] Стр. 37: chart  (chart=0.264, image=0.069, conf=0.793)

# %% [markdown]
# ---
# ## 4. Этап 3 — Транскрипция графиков (OCR + CLIP + BLIP + GPT)
#
# Каждый **chart** проходит полный анализ:
# 1. **OCR** — читает текст с графика (подписи, числа)
# 2. **CLIP** — определяет подтип (столбчатая, линейная, круговая...)
# 3. **BLIP** — генерирует описание на английском
# 4. **GPT** — переводит и дополняет описание на русском
#
# Результат: **транскрипция** — текстовое описание графика для RAG.

# %%
from src.preprocessing.chart_analyzer import ChartAnalyzer
from src.preprocessing.ocr_processor import OCRProcessor

ocr = OCRProcessor()
chart_analyzer = ChartAnalyzer(
    ocr_processor=ocr,
    use_clip=True,
    use_blip=True,
    use_opencv=True,
)

chart_only_images = [img for img, cls in chart_images]
chart_results = []

if chart_only_images:
    chart_results = chart_analyzer.analyze_batch(chart_only_images)
    print(f'Проанализировано графиков: {len(chart_results)}')
    for i, r in enumerate(chart_results):
        print(f'\n--- График {i+1} (стр. {r.page_num}) ---')
        print(f'  Подтип (CLIP): {r.chart_subtype_ru} (conf={r.confidence:.2f})')
        blip = r.blip_caption
        print(f'  BLIP: {blip[:80]}...' if len(blip) > 80 else f'  BLIP: {blip}')
        ocr_t = r.ocr_text
        print(f'  OCR текст: {ocr_t[:100]}...' if len(ocr_t) > 100 else f'  OCR текст: {ocr_t}')
        gpt = r.gpt_description
        print(f'  GPT описание: {gpt[:150]}...' if len(gpt) > 150 else f'  GPT описание: {gpt}')
else:
    print('Графики не найдены в документе.')
# Out:
# src.preprocessing.chart_analyzer -   Анализ графика [1/11]: стр. 5, 1087x1536px
# src.preprocessing.chart_analyzer - Загрузка CLIP для анализа графиков...
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/openai/clip-vit-base-patch32/3d74acf9a28c67741b2f4f2ea7635f0aaf6f0268/config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/pytorch_model.bin "HTTP/1.1 302 Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: GET https://huggingface.co/api/models/openai/clip-vit-base-patch32 "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/models/openai/clip-vit-base-patch32/commits/main "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/models/openai/clip-vit-base-patch32/discussions?p=0 "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/models/openai/clip-vit-base-patch32/commits/refs%2Fpr%2F66 "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/refs%2Fpr%2F66/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/refs%2Fpr%2F66/model.safetensors "HTTP/1.1 302 Found"
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# CLIPModel LOAD REPORT from: openai/clip-vit-base-patch32
# Key                                  | Status     |  |
# -------------------------------------+------------+--+-
# vision_model.embeddings.position_ids | UNEXPECTED |  |
# text_model.embeddings.position_ids   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# httpx - HTTP Request: GET https://huggingface.co/api/models/openai/clip-vit-base-patch32/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/chat_template.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/audio_tokenizer_config.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/openai/clip-vit-base-patch32/3d74acf9a28c67741b2f4f2ea7635f0aaf6f0268/preprocessor_config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/openai/clip-vit-base-patch32/3d74acf9a28c67741b2f4f2ea7635f0aaf6f0268/preprocessor_config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/openai/clip-vit-base-patch32/3d74acf9a28c67741b2f4f2ea7635f0aaf6f0268/config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/openai/clip-vit-base-patch32/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/openai/clip-vit-base-patch32/3d74acf9a28c67741b2f4f2ea7635f0aaf6f0268/tokenizer_config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/models/openai/clip-vit-base-patch32/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: GET https://huggingface.co/api/models/openai/clip-vit-base-patch32/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# src.preprocessing.chart_analyzer - CLIP загружен.
# src.preprocessing.chart_analyzer - Загрузка BLIP (Salesforce/blip-image-captioning-large)...
# httpx - HTTP Request: GET https://huggingface.co/api/models/Salesforce/blip-image-captioning-large/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/Salesforce/blip-image-captioning-large/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/Salesforce/blip-image-captioning-large/resolve/main/chat_template.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/Salesforce/blip-image-captioning-large/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/Salesforce/blip-image-captioning-large/resolve/main/audio_tokenizer_config.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/Salesforce/blip-image-captioning-large/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/Salesforce/blip-image-captioning-large/resolve/main/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/blip-image-captioning-large/353689b859fcf0523410b1806dace5fb46ecdf41/preprocessor_config.json "HTTP/1.1 200 OK"
# The image processor of type `BlipImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# httpx - HTTP Request: HEAD https://huggingface.co/Salesforce/blip-image-captioning-large/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/Salesforce/blip-image-captioning-large/resolve/main/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/blip-image-captioning-large/353689b859fcf0523410b1806dace5fb46ecdf41/preprocessor_config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/Salesforce/blip-image-captioning-large/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/blip-image-captioning-large/353689b859fcf0523410b1806dace5fb46ecdf41/config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/Salesforce/blip-image-captioning-large/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/blip-image-captioning-large/353689b859fcf0523410b1806dace5fb46ecdf41/tokenizer_config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/models/Salesforce/blip-image-captioning-large/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: GET https://huggingface.co/api/models/Salesforce/blip-image-captioning-large/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/Salesforce/blip-image-captioning-large/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/blip-image-captioning-large/353689b859fcf0523410b1806dace5fb46ecdf41/config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/Salesforce/blip-image-captioning-large/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# Loading weights:   0%|          | 0/616 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie text_decoder.bert.embeddings.word_embeddings.weight to text_decoder.cls.predictions.decoder.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# BlipForConditionalGeneration LOAD REPORT from: Salesforce/blip-image-captioning-large
# Key                                       | Status     |  |
# ------------------------------------------+------------+--+-
# text_decoder.bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# httpx - HTTP Request: HEAD https://huggingface.co/Salesforce/blip-image-captioning-large/resolve/main/generation_config.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/Salesforce/blip-image-captioning-large/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Salesforce/blip-image-captioning-large/353689b859fcf0523410b1806dace5fb46ecdf41/config.json "HTTP/1.1 200 OK"
# src.preprocessing.chart_analyzer - BLIP загружен.
# src.preprocessing.chart_analyzer - GPT ошибка: 'content'
# src.preprocessing.chart_analyzer -   Анализ графика [2/11]: стр. 14, 792x593px
# src.preprocessing.chart_analyzer -   GPT описание (448 символов)
# src.preprocessing.chart_analyzer -   Анализ графика [3/11]: стр. 23, 266x190px
# src.preprocessing.chart_analyzer - GPT ошибка: 'content'
# src.preprocessing.chart_analyzer -   Анализ графика [4/11]: стр. 23, 347x345px
# src.preprocessing.chart_analyzer - GPT ошибка: 'content'
# src.preprocessing.chart_analyzer -   Анализ графика [5/11]: стр. 28, 272x278px
# src.preprocessing.chart_analyzer - GPT ошибка: 'content'
# src.preprocessing.chart_analyzer -   Анализ графика [6/11]: стр. 28, 356x262px
# src.preprocessing.chart_analyzer - GPT ошибка: 'content'
# src.preprocessing.chart_analyzer -   Анализ графика [7/11]: стр. 31, 513x325px
# src.preprocessing.chart_analyzer - GPT ошибка: 'content'
# src.preprocessing.chart_analyzer -   Анализ графика [8/11]: стр. 33, 349x194px
# src.preprocessing.chart_analyzer - GPT ошибка: 'content'
# src.preprocessing.chart_analyzer -   Анализ графика [9/11]: стр. 33, 350x190px
# src.preprocessing.chart_analyzer - GPT ошибка: 'content'
# src.preprocessing.chart_analyzer -   Анализ графика [10/11]: стр. 34, 336x194px
# src.preprocessing.chart_analyzer - GPT ошибка: 'content'
# src.preprocessing.chart_analyzer -   Анализ графика [11/11]: стр. 37, 398x272px
# src.preprocessing.chart_analyzer - GPT ошибка: 'content'
# Проанализировано графиков: 11
#
# --- График 1 (стр. 5) ---
#   Подтип (CLIP): Таблица с данными (conf=0.44)
#   BLIP: this image shows a black document with a picture of a person in a suit
#   OCR текст: ТРАФИК у
# | Нбпаевонанив разделов, | Срожи предотаврезния Понмечание
# перечень научному руководжтело
# т...
#   GPT описание: Таблица с данными. (BLIP: this image shows a black document with a picture of a person in a suit). Ключевые слова: ТРАФИК, Нбпаевонанив, разделов, Сро...
#
# --- График 2 (стр. 14) ---
#   Подтип (CLIP): Блок-схема (conf=0.82)
#   BLIP: this image shows a diagram of a circular space station
#   OCR текст: aii
# о COT |
# 5. é Xe ТЕ
# 2 =
#   GPT описание: Тип визуализации: блок‑схема.
# На схеме изображён круглый космический корабль‑стоянка, представленный в виде упрощённого наброска с обозначением осно...
#
# --- График 3 (стр. 23) ---
#   Подтип (CLIP): Диаграмма с областями (conf=0.26)
#   BLIP: this image shows a diagram of a circle with a center and a center
#   OCR текст:
#   GPT описание: Диаграмма с областями. (BLIP: this image shows a diagram of a circle with a center and a center).
#
# --- График 4 (стр. 23) ---
#   Подтип (CLIP): Блок-схема (conf=0.55)
#   BLIP: this image shows a diagram of a water circuit
#   OCR текст: одета сисик е-е
# а і
# ез»
# АСВ
# hv. Water
# electrolyte)
# + SVB
# 5
# ,9 1 Counter-
# Ferroelectric t electrode
# C...
#   GPT описание: Блок-схема. (BLIP: this image shows a diagram of a water circuit). Ключевые слова: одета, сисик, АСВ, Water, electrolyte, SVB, Counter, Ferroelectric.
#
# --- График 5 (стр. 28) ---
#   Подтип (CLIP): Круговая диаграмма (conf=0.44)
#   BLIP: this image shows a white pill on a ruler next to a white pill
#   OCR текст:
#   GPT описание: Круговая диаграмма. (BLIP: this image shows a white pill on a ruler next to a white pill).
#
# --- График 6 (стр. 28) ---
#   Подтип (CLIP): Гистограмма (conf=0.63)
#   BLIP: this image shows a plot of the hypother and hypother
#   OCR текст: > =
#   GPT описание: Гистограмма. (BLIP: this image shows a plot of the hypother and hypother).
#
# --- График 7 (стр. 31) ---
#   Подтип (CLIP): Гистограмма (conf=0.79)
#   BLIP: this image shows a plot of the average time of a person to run
#   OCR текст: е“ удержание
# = see o охлаждение
#   GPT описание: Гистограмма. (BLIP: this image shows a plot of the average time of a person to run). Ключевые слова: удержание, see, охлаждение.
#
# --- График 8 (стр. 33) ---
#   Подтип (CLIP): Гистограмма (conf=0.38)
#   BLIP: this image shows a red substance with a square shape and a line of numbers
#   OCR текст: BNO eae х
# = a 25
# 2» 2
# , 255.. A 15
# Қары б
# > 5
#   GPT описание: Гистограмма. (BLIP: this image shows a red substance with a square shape and a line of numbers). Ключевые слова: BNO, eae, ары.
#
# --- График 9 (стр. 33) ---
#   Подтип (CLIP): Гистограмма (conf=0.66)
#   BLIP: this image shows a plot of a piece of bread with a line of length
#   OCR текст: тт rarer
# 15
# 9
# 200
# 300
# 5 = 1000 77
# оо `В < 00
# 10 жо 40 69
#   GPT описание: Гистограмма. (BLIP: this image shows a plot of a piece of bread with a line of length). Ключевые слова: rarer.
#
# --- График 10 (стр. 34) ---
#   Подтип (CLIP): Точечная диаграмма (conf=0.62)
#   BLIP: this image shows a pizza with a square of toppings on it
#   OCR текст: 5 52 г us 2
#   GPT описание: Точечная диаграмма. (BLIP: this image shows a pizza with a square of toppings on it).
#
# --- График 11 (стр. 37) ---
#   Подтип (CLIP): Гистограмма (conf=0.83)
#   BLIP: this image shows the results of a single - cell cell phone signal
#   OCR текст: Е ЗЕ 8
# 4000 Б Е ЕЗ
# 3 узо 2c.
# РО ere
# 53300 АОИ БИН МООА
# EOE
# ево
#   GPT описание: Гистограмма. (BLIP: this image shows the results of a single - cell cell phone signal). Ключевые слова: узо, ere, АОИ, БИН, МООА, EOE, ево.

# %% [markdown]
# ---
# ## 5. Визуализация: Оригинал графика → Транскрипция
#
# Наглядная демонстрация для научного руководителя:
# **слева** — исходное изображение, **справа** — результат анализа системы.

# %%
import textwrap

if chart_results and chart_only_images:
    n_charts = min(len(chart_results), 6)

    for idx in range(n_charts):
        img_data = chart_only_images[idx]
        analysis = chart_results[idx]

        fig, (ax_img, ax_text) = plt.subplots(
            1, 2, figsize=(14, 5),
            gridspec_kw={'width_ratios': [1, 1.2]}
        )

        # Левая часть — оригинальное изображение
        ax_img.imshow(img_data.image)
        ax_img.set_title(
            f'Оригинал (стр. {analysis.page_num})',
            fontsize=13, fontweight='bold'
        )
        ax_img.axis('off')

        # Правая часть — транскрипция
        ax_text.axis('off')

        lines = []
        lines.append(f"Тип: {analysis.chart_subtype_ru}")
        lines.append(f"Уверенность CLIP: {analysis.confidence:.0%}")
        lines.append("")
        if analysis.blip_caption:
            lines.append(f"BLIP (EN): {analysis.blip_caption}")
            lines.append("")
        if analysis.gpt_description:
            wrapped = textwrap.fill(analysis.gpt_description, width=50)
            lines.append(f"Описание (RU):")
            lines.append(wrapped)
            lines.append("")
        if analysis.ocr_text:
            ocr_short = analysis.ocr_text[:150]
            if len(analysis.ocr_text) > 150:
                ocr_short += '...'
            lines.append(f"OCR: {ocr_short}")

        transcription = "\n".join(lines)

        ax_text.text(
            0.05, 0.95, transcription,
            transform=ax_text.transAxes,
            verticalalignment='top',
            fontsize=10, fontfamily='monospace',
            bbox=dict(
                boxstyle='round,pad=0.5',
                facecolor='#F8F9FA',
                edgecolor='#DEE2E6', alpha=0.9
            )
        )
        ax_text.set_title('Транскрипция', fontsize=13, fontweight='bold')

        plt.tight_layout()
        save_path = f'report/img/chart_recognition_{idx+1}.png'
        plt.savefig(save_path, dpi=150, bbox_inches='tight')
        plt.show()
        print(f'Сохранено: {save_path}')
        print()
else:
    print('Нет графиков для визуализации.')
# Out:
# Сохранено: report/img/chart_recognition_1.png
# Сохранено: report/img/chart_recognition_2.png
# Сохранено: report/img/chart_recognition_3.png
# Сохранено: report/img/chart_recognition_4.png
# Сохранено: report/img/chart_recognition_5.png
# Сохранено: report/img/chart_recognition_6.png

# %% [markdown]
# ---
# ## 6. Markdown и Chunking
#
# Все блоки (текст + графики + фото) собираются в Markdown → разбиваются на чанки.

# %%
from src.preprocessing.markdown_builder import MarkdownBuilder
from src.rag.chunker import MarkdownChunker
from src.layout.block import Block

# Создаём Block-объекты для chart и image
chart_blocks = []
for img_data, analysis in zip(chart_only_images, chart_results):
    chart_blocks.append(Block(
        block_type='chart',
        bbox=img_data.bbox,
        page_num=img_data.page_num + 1,
        text=analysis.to_chunk_text(),
        metadata=analysis.to_dict(),
    ))

image_blocks = []
for img_data, cls in photo_images:
    image_blocks.append(Block(
        block_type='image',
        bbox=img_data.bbox,
        page_num=img_data.page_num + 1,
        metadata={'image_path': img_data.saved_path or '', 'ocr_text': ''},
    ))

final_blocks = all_blocks + chart_blocks + image_blocks
print(f'Итого блоков для Markdown: {len(final_blocks)}')
print(f'  Текстовых: {len(all_blocks)}')
print(f'  Графиков:  {len(chart_blocks)}')
print(f'  Фото:      {len(image_blocks)}')

# Markdown
builder = MarkdownBuilder()
source_name = os.path.basename(PDF_PATH)
markdown = builder.build(final_blocks, source_name)
print(f'\nMarkdown: {len(markdown)} символов')

# Сохранение
md_dir = os.path.join('data/indexes', doc_name)
os.makedirs(md_dir, exist_ok=True)
md_path = os.path.join(md_dir, source_name + '.md')
builder.save(markdown, md_path)

# Chunking
chunker = MarkdownChunker(
    max_chunk_size=1000, chunk_overlap=100, min_chunk_size=50
)
chunks = chunker.chunk_markdown(markdown, source=source_name)
print(f'Чанков: {len(chunks)}')
# Out:
# Итого блоков для Markdown: 249
#   Текстовых: 214
#   Графиков:  11
#   Фото:      24
#
# Markdown: 69262 символов
# src.preprocessing.markdown_builder - Markdown saved to data/indexes/diploma_example/diploma_example.pdf.md
# src.rag.chunker - Created 76 chunks from 'diploma_example.pdf'
# Чанков: 76

# %%
# Пример чанка с транскрипцией графика (если есть)
chart_chunk_found = False
for c in chunks:
    if '[Тип:' in c.text or 'График' in c.text:
        print('=== Пример чанка с транскрипцией графика ===')
        print(c.text)
        print(f'\n(Размер: {len(c.text)} символов)')
        chart_chunk_found = True
        break

if not chart_chunk_found:
    print('Пример текстового чанка:')
    print(chunks[0].text[:500])
# Out:
# === Пример чанка с транскрипцией графика ===
# -- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
#
# | Температура подложки измерялась термопарой вида “K”. Перед | осаждением проводилась откачка камеры вплоть до вакуума 10 -6 | Торр, далее | в камеру запускался поток О 2 . Энергия лазера и частота задавалась | программой с пульта управления. Лазерный луч фокусировался линзой с | целью получения пучка диаметр 1мм, что был нацелен через оптическое |
# | --- | --- | --- | --- | --- | --- |
#
# ---
# *Страница 31*
#
# окошко в центр вращающейся мишени. Энергия лазера воздействовала на  поверхность PZT мишени с частотой с 5 вплоть до 20Гц, образовывая факел  из испаренных элементов мишени которые осаждались в подогретую  поверхность подложки.
#
# Рисунок 3.9 – График программируемого нагрева термостолика
#
# | Пленки PZT осаждались в подложке химически расчищенного Ni 100 | согласно характеристикам, отмеченным в таблице 3.1. |
# | --- | --- |
#
# Таблица 3.1- Параметры осаждения пленок в камере PLD
#
# (Размер: 988 символов)

# %%
sizes = [len(c.text) for c in chunks]
fig, ax = plt.subplots(figsize=(8, 4))
ax.hist(sizes, bins=20, color='#45B7D1', edgecolor='white', alpha=0.8)
ax.axvline(
    x=sum(sizes)/len(sizes), color='#FF6B6B', linestyle='--',
    label=f'Среднее: {sum(sizes)/len(sizes):.0f} символов'
)
ax.set_xlabel('Размер чанка (символы)')
ax.set_ylabel('Количество')
ax.set_title('Распределение размеров чанков')
ax.legend()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('report/img/chunk_sizes.png', dpi=150, bbox_inches='tight')
plt.show()
print(f'Мин: {min(sizes)}, Макс: {max(sizes)}, Среднее: {sum(sizes)/len(sizes):.0f}')
# Out:
# Мин: 118, Макс: 3646, Среднее: 959

# %% [markdown]
# ---
# ## 7. Эмбеддинги (SBERT) и индексация (FAISS)

# %%
from src.rag.embedder import MultimodalEmbedder
from src.rag.vector_store import FAISSVectorStore

embedder = MultimodalEmbedder(use_clip=False)
embeddings = embedder.embed_chunks(chunks)
print(f'Эмбеддинги: shape={embeddings.shape}')
print(f'Размерность: {embeddings.shape[1]}')

# FAISS
vector_store = FAISSVectorStore(dimension=embedder.dimension)
metadata_list = [chunk.to_dict() for chunk in chunks]
vector_store.add(embeddings, metadata_list)

# Сохранение
index_dir = os.path.join('data/indexes', doc_name)
os.makedirs(index_dir, exist_ok=True)
vector_store.save(index_dir)
print(f'Индекс сохранён: {index_dir}')
print(f'Чанков в индексе: {vector_store.size}')
# Out:
# src.rag.embedder - Loading text embedding model: paraphrase-multilingual-MiniLM-L12-v2
# sentence_transformers.SentenceTransformer - Use pytorch device_name: cpu
# sentence_transformers.SentenceTransformer - Load pretrained SentenceTransformer: paraphrase-multilingual-MiniLM-L12-v2
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/modules.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/modules.json "HTTP/1.1 200 OK"
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/config_sentence_transformers.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/config_sentence_transformers.json "HTTP/1.1 200 OK"
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/config_sentence_transformers.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/README.md "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/README.md "HTTP/1.1 200 OK"
# README.md: 0.00B [00:00, ?B/s]
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/modules.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/sentence_bert_config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/sentence_bert_config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/sentence_bert_config.json "HTTP/1.1 200 OK"
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/config.json "HTTP/1.1 200 OK"
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# httpx - HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/xet-read-token/e8f8c211226b894fcb81acc59f3b34ba3efd5f42 "HTTP/1.1 200 OK"
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/tokenizer_config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/tokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json:   0%|          | 0.00/526 [00:00<?, ?B/s]
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/tokenizer_config.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/tokenizer.json "HTTP/1.1 302 Found"
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/tokenizer.model "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/added_tokens.json "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/special_tokens_map.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/special_tokens_map.json "HTTP/1.1 200 OK"
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
# httpx - HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2 "HTTP/1.1 200 OK"
# httpx - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/1_Pooling/config.json "HTTP/1.1 307 Temporary Redirect"
# httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/1_Pooling%2Fconfig.json "HTTP/1.1 200 OK"
# httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/1_Pooling%2Fconfig.json "HTTP/1.1 200 OK"
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# httpx - HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2 "HTTP/1.1 200 OK"
# src.rag.embedder - Text embedding model loaded.
# src.rag.vector_store - Added 76 vectors. Total: 76
# src.rag.vector_store - Saved index (76 vectors) to data/indexes/diploma_example
# Эмбеддинги: shape=(76, 384)
# Размерность: 384
# Индекс сохранён: data/indexes/diploma_example
# Чанков в индексе: 76

# %%
from sklearn.manifold import TSNE
import numpy as np

if embeddings.shape[0] > 5:
    perplexity = min(30, embeddings.shape[0] - 1)
    tsne = TSNE(n_components=2, random_state=42, perplexity=perplexity)
    coords = tsne.fit_transform(embeddings)

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.scatter(
        coords[:, 0], coords[:, 1],
        c='#45B7D1', alpha=0.6, s=30, edgecolors='white'
    )
    ax.set_title('t-SNE визуализация эмбеддингов чанков')
    ax.set_xlabel('t-SNE 1')
    ax.set_ylabel('t-SNE 2')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.tight_layout()
    plt.savefig('report/img/tsne_embeddings.png', dpi=150, bbox_inches='tight')
    plt.show()
    print('Сохранено: report/img/tsne_embeddings.png')
else:
    print('Слишком мало чанков для t-SNE')
# Out:
# Сохранено: report/img/tsne_embeddings.png

# %% [markdown]
# ---
# ## 8. RAG: Вопрос-Ответ по документу
#
# Задаём вопросы — система ищет релевантные чанки через FAISS и генерирует ответ через GPT.
# Включены вопросы как по тексту, так и **по графикам** для проверки транскрипции.

# %%
from src.rag.retriever import MultimodalRetriever
from src.rag.generator import RAGGenerator

retriever = MultimodalRetriever(
    embedder=embedder,
    vector_store=vector_store,
    top_k=5,
)
generator = RAGGenerator(model_name='gpt-oss-20b')
print(f'LLM доступен: {generator.is_available()}')

def ask(question):
    """Задать вопрос RAG-системе."""
    print(f'\n{"=" * 60}')
    print(f'Вопрос: {question}')
    print(f'{"=" * 60}')

    # Retrieval
    results = retriever.retrieve(question, top_k=5)
    context_parts = []
    for i, r in enumerate(results, 1):
        chunk_type = r.get('type', 'text')
        label = 'график' if chunk_type == 'image_caption' else 'текст'
        context_parts.append(f'[Фрагмент {i}, {label}]:\n{r["text"]}')

    context = '\n\n---\n\n'.join(context_parts)

    # Generation
    result = generator.generate(question, context)

    print(f'\nОтвет ({result["model"]}):')
    print(result['answer'])

    print(f'\nИсточники:')
    for i, r in enumerate(results[:3], 1):
        score = r.get('score', 0)
        page = r.get('page', '?')
        preview = r.get('text', '')[:80]
        print(f'  [{i}] Стр. {page}, score={score:.4f}: {preview}...')

    return result
# Out:
# LLM доступен: True

# %%
# Вопрос 1: общий
q1 = ask('О чём этот документ?')
# Out:
# src.rag.retriever - Retrieved 5 chunks for query: 'О чём этот документ?...' (filter=None)
# ============================================================
# Вопрос: О чём этот документ?
# ============================================================
#
# Ответ (gpt-oss-20b):
# Документ представляет собой дипломную работу, посвящённую исследованию установки импульсного лазерного осаждения (PLD) и подготовке тонких пленок Pb(Zr₀.₅₂Ti₀.₄₈)O₃ (PZT). Цель работы – получение этих пленок для фотокаталитического расщепления воды с целью производства водорода, что рассматривается как альтернативный источник энергии в условиях энергетического кризиса. В работе описываются объект и цель исследования, актуальность темы, а также содержится введение, четыре главы, 39 страниц, 26 рисунков и 21 источник литературы.
#
# Источники:
#   [1] Стр. 14, score=0.5012: ![Таблица с данными, стр. 5](data/images/diploma_example/diploma_example_p5_img3...
#   [2] Стр. 10, score=0.3930: | Дипломная работа состоит из 39 страниц, 26 рисунков, 21 | использованных источ...
#   [3] Стр. 2, score=0.3703: зображение со стр. 33](data/images/diploma_example/diploma_example_p33_img22.png...

# %%
# Вопрос 2: технологии
q2 = ask('Какие методы и технологии описаны в документе?')
# Out:
# src.rag.retriever - Retrieved 5 chunks for query: 'Какие методы и технологии описаны в документе?...' (filter=None)
# ============================================================
# Вопрос: Какие методы и технологии описаны в документе?
# ============================================================
#
# Ответ (gpt-oss-20b):
# В документе рассматриваются следующие методы и технологии, применяемые для получения тонких пленок PZT и их последующего использования:
#
# 1. **Импульсное лазерное осаждение (PLD)** – основной метод, описанный в работе. В нём материал мишени абляцируется лазером, а осаждённый материал формирует пленку на подложке. В тексте подробно описаны параметры PLD (энергия, длительность импульса, частота, давление, температура подложки) и три режима роста пленки (ступенчатый, послойный, слияние).
#
# 2. **Молекулярно‑лучевая эпитаксия (MBE)** – упомянута как один из методов получения кристаллических тонких пленок, особенно для перовскитовых структур. Отмечены преимущества (контроль границ раздела до атомного слоя) и недостатки (контроль стехиометрии, высокая стоимость).
#
# 3. **Распыление (магнетронное распыление, в частности высокочастотное магнетронное распыление)** – описан как способ удаления атомов с поверхности мишени и осаждения пленки. Указаны преимущества (быстрая скорость осаждения, однородность толщины) и недостатки (контроль количества испаряемого материала, потеря Pb и PbO).
#
# 4. **Фотокаталитическое расщепление воды** – технология, в которой применяются тонкие пленки PZT как фотоферроэлектрики для производства водорода. Это не метод изготовления пленки, а конечное применение полученных материалов.
#
# Таким образом, в документе рассматриваются PLD, MBE, магнетронное распыление и фотокаталитический процесс как ключевые методы и технологии.
#
# Источники:
#   [1] Стр. 10, score=0.5078: | Дипломная работа состоит из 39 страниц, 26 рисунков, 21 | использованных источ...
#   [2] Стр. 13, score=0.5058: ется интересным материалом в  твердотельных технологиях, в фотокатализе и в топл...
#   [3] Стр. 7, score=0.4999: | Дипломдық жұмыс 39 беттен, 26 суреттен, 21 пайдаланылған әдебиет | көздерінен,...

# %%
# Вопрос 3: данные на графиках (проверка транскрипции)
q3 = ask('Какие данные представлены на графиках и диаграммах в документе?')
# Out:
# src.rag.retriever - Retrieved 5 chunks for query: 'Какие данные представлены на графиках и диаграммах...' (filter=None)
# ============================================================
# Вопрос: Какие данные представлены на графиках и диаграммах в документе?
# ============================================================
#
# Ответ (gpt-oss-20b):
# В документе представлены следующие визуальные элементы и типы данных, которые они иллюстрируют:
#
# | № | Вид графика/диаграммы | Описание содержимого (по доступной информации) |
# |---|-----------------------|----------------------------------------------|
# | 1 | Таблица (страница 5) | Таблица с данными, в которой, судя по OCR‑тексту, упоминаются «ТРАФИК» и «научный руководитель». Точные значения таблицы не видны из-за искажённого текста, но, вероятно, это статистика по трафику/потокам. |
# | 2 | Гистограмма (страница 28) | Гистограмма, обозначенная как «plot of the hypother and hypother». Текстовое описание не даёт конкретных чисел, но график, скорее всего, показывает распределение какого‑то показателя, названного «hypother». |
# | 3 | Диаграмма с областями (страница 23) | Диаграмма, описанная как «diagram of a circle with a center and a center». Это, по сути, круговая (пироговая) диаграмма, где области представляют доли какого‑то целого. Конкретные доли не указаны. |
# | 4 | Гистограмма (страница 33) | Гистограмма, в которой видны числовые значения: 25, 2, 255, 15 и > 5. Текст «BNO eae» и «ary» указывает на названия осей или категорий, но точный контекст не ясен. |
# | 5 | Блок‑схема (страница 14) | Блок‑схема космического корабля‑стоянки. На схеме изображены основные модули (питание, жизнеобеспечение, научные лаборатории и т.д.) и их взаимосвязи. В схеме нет количественных измерений или трендов – она лишь демонстрирует структуру и связи систем. |
#
# Таким образом, в документе находятся таблица с данными о трафике, две гистограммы (одна из которых содержит конкретные числовые значения), круговая диаграмма и блок‑схема, показывающая архитектуру космического корабля‑стоянки.
#
# Источники:
#   [1] Стр. 14, score=0.6010: ![Таблица с данными, стр. 5](data/images/diploma_example/diploma_example_p5_img3...
#   [2] Стр. 31, score=0.5819: ![Гистограмма, стр. 28](data/images/diploma_example/diploma_example_p28_img16.pn...
#   [3] Стр. None, score=0.5588: ![Диаграмма с областями, стр. 23](data/images/diploma_example/diploma_example_p2...

# %%
# Вопрос 4: тренды из графиков
q4 = ask('Какие тренды или изменения показаны на диаграммах?')
# Out:
# src.rag.retriever - Retrieved 5 chunks for query: 'Какие тренды или изменения показаны на диаграммах?...' (filter=None)
# ============================================================
# Вопрос: Какие тренды или изменения показаны на диаграммах?
# ============================================================
#
# Ответ (gpt-oss-20b):
# Невозможно определить конкретные тренды или изменения, поскольку в предоставленном контексте отсутствуют подробные описания данных, осей, подписи или числовые значения, которые позволили бы проанализировать динамику на диаграммах. Транскрипции и OCR‑тексты содержат лишь общие указания (например, «гистограмма», «диаграмма с областями», «среднее время бега»), но не дают информации о направлениях изменений, сравнениях или тенденциях. Поэтому на основании данного материала нельзя ответить, какие именно тренды или изменения показаны на диаграммах.
#
# Источники:
#   [1] Стр. None, score=0.4681: ![Диаграмма с областями, стр. 23](data/images/diploma_example/diploma_example_p2...
#   [2] Стр. 33, score=0.4620: ![Гистограмма, стр. 31](data/images/diploma_example/diploma_example_p31_img21.pn...
#   [3] Стр. 31, score=0.4317: ![Гистограмма, стр. 28](data/images/diploma_example/diploma_example_p28_img16.pn...

# %%
# Вопрос 5: мультимодальный (текст + графики)
q5 = ask('Сравни данные из таблиц и графиков документа.')
# Out:
# src.rag.retriever - Retrieved 5 chunks for query: 'Сравни данные из таблиц и графиков документа....' (filter=None)
# ============================================================
# Вопрос: Сравни данные из таблиц и графиков документа.
# ============================================================
#
# Ответ (gpt-oss-20b):
# В документе представлена только одна таблица с конкретными числовыми данными – **Таблица 3.1** (параметры осаждения пленок в камере PLD). В ней указаны:
#
# | Параметр | Значения |
# |----------|----------|
# | Температура осаждения | 500 °C, 550 °C, 600 °C, 650 °C, 700 °C |
# | Давление (мТorr) | 2 × 10⁻⁶ (для всех образцов) |
# | Частота лазера | 5 Гц |
# | Давление газа | 200 мТorr |
# | Время осаждения | 60 мин |
# | Энергия лазера | 370 мДж |
# | Мощность лазера | 23 кВ (или кВт, в зависимости от единицы) |
#
# Графические элементы (гистограммы на страницах 28, 31, 33) в предоставленном контексте не содержат извлечённых числовых значений – в OCR‑тексте присутствуют лишь случайные символы и небольшие числа (например, «15», «9», «200», «300», «5 = 1000 77»), которые не позволяют однозначно определить, что именно измеряется и какие величины они представляют.
#
# **Сравнение**
# - **Таблица**: предоставляет строго заданные параметры процесса осаждения, позволяя увидеть, как меняется температура осаждения при прочих условиях, остающихся постоянными.
# - **Графики**: без конкретных числовых данных не позволяют провести количественное сравнение с таблицей. Они, скорее всего, иллюстрируют распределения какой‑то измеряемой величины (например, размер зерен, время удержания, частота событий), но точных значений в тексте нет.
#
# Таким образом, на основании предоставленного контекста можно лишь отметить, что таблица содержит детальные параметры процесса, тогда как графики дают визуальное представление о распределениях, но не содержат достаточных числовых данных для прямого сравнения с таблицей.
#
# Источники:
#   [1] Стр. 14, score=0.3941: ![Таблица с данными, стр. 5](data/images/diploma_example/diploma_example_p5_img3...
#   [2] Стр. 26, score=0.3854: кам, отмеченным в таблице 3.1. |
# | --- | --- |
#
# Таблица 3.1- Параметры осаждения...
#   [3] Стр. 31, score=0.3692: ![Гистограмма, стр. 28](data/images/diploma_example/diploma_example_p28_img16.pn...

# %% [markdown]
# ---
# ## 9. Итоговая статистика

# %%
print('=' * 50)
print('ИТОГОВАЯ СТАТИСТИКА')
print('=' * 50)
print(f'Документ:  {os.path.basename(PDF_PATH)}')
print(f'Страниц:   {len(fitz.open(PDF_PATH))}')
print()
print('Блоки (этап 1):')
for t, c in sorted(type_counts.items(), key=lambda x: -x[1]):
    print(f'  {t:10s}: {c}')
print()
print('Изображения (этап 2):')
print(f'  Всего извлечено: {len(extracted_images)}')
print(f'  Charts:          {len(chart_images)}')
print(f'  Images:          {len(photo_images)}')
print()
print('Транскрипции (этап 3):')
print(f'  Графиков проанализировано: {len(chart_results)}')
print()
print('Индекс:')
print(f'  Чанков:      {len(chunks)}')
print(f'  Размерность: {embeddings.shape[1]}')
print(f'  Размер:      {vector_store.size}')
# Out:
# ==================================================
# ИТОГОВАЯ СТАТИСТИКА
# ==================================================
# Документ:  diploma_example.pdf
# Страниц:   41
#
# Блоки (этап 1):
#   text      : 77
#   table     : 77
#   no_text   : 38
#   header    : 12
#   list      : 10
#
# Изображения (этап 2):
#   Всего извлечено: 35
#   Charts:          11
#   Images:          24
#
# Транскрипции (этап 3):
#   Графиков проанализировано: 11
#
# Индекс:
#   Чанков:      76
#   Размерность: 384
#   Размер:      76
